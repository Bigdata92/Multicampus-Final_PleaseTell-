# %%
import sys, os
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('Captioning_test_Okt.py'))))
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('KoGPT2_Wise.py'))))

import Captioning_Okt as cp
import KoGPT2_Wise as kgbw

# %%
from PIL import Image
result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행05.jpg')
result = ' '.join(result[:-1])
sequence = kgbw.result_sequence(result, 64)
print(sequence)
Image.open('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행05.jpg')
# Out:
# 즉 최고 지도자는 한 사람의 평범한 관리자여야 한다. 모든 사람은 자기가 하고 싶은 일을 해야 한다.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x226 at 0x15E8B978CD0>
