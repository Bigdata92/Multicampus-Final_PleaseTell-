# %%
# 하위 폴더에서 상위폴더의 파이썬 파일을 불러 사용하기 위해 필요한 파일
import sys, os
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('Captioning_test_Okt.py'))))
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('KoGPT2_Branch.py'))))

import KoGPT2_Branch as kgb
import Captioning_Okt as cp

# %%
# result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/1.jpg')
# result = ' '.join(result[:-1])
# sequence = kgb.generate_text(result, 128)
# sequence = kgb.spell_check(sequence)
# sequence

# %%
# import re
# sequence = re.sub('[^ㄱ-ㅎㅏ-ㅣ가-힣0-9., ]', ' ', sequence)
# sequence

# %%
# sequence = sequence.split(f'{result}, ')[1]
# sequence

# %%
# sequence = sequence.replace('  ', ' ')
# sequence =  sequence.replace('. ', '.. ')
# sequence = ' '.join(sequence.split('. ')[:-1])
# sequence

# %%
# sequence = kgb.spell_check(sequence)
# sequence

# %%
# 위의 코드 종합
# sequence1 = kgb.generate_text(result, 128)
# sequence2 = kgb.spell_check(sequence1)
# sequence3 = sequence2.split(f'{result}, ')[1]
# sequence4 = sequence3.replace('  ', ' ')
# sequence5 =  sequence4.replace('. ', '.. ')
# sequence6 = ' '.join(sequence5.split('. ')[:-1])
# sequence7 = kgb.spell_check(sequence6)
# sequence5.split('. ')[:-1]

# %%
from PIL import Image
result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행01.jpg')
result = ' '.join(result[:-1])
sequence = kgb.result_sequence(result, 128)
print(sequence)
Image.open('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행01.jpg')
# Out:
# 라는 문장으로 나와서 나는 조금 슬퍼졌다. 내가 혼자 그리 먼 곳에 살고, 엄마 집에 할아버지 없인 살아 봤자 너네로 클 것 같아서 더 자주 오게 해서의 영화티켓을 사 주겠다는 것도 세상에 하고 싶은 일처럼 느껴졌고, 설령 엄마, 아빠와 함께 나를 잃은 아이들이더라도 이런 기분을 느끼고 싶었다. 또 다른 유명한 그림은 파울 클레의 그림이었다. 가난하고 소심한 소년이었던 열세 남짓한 내게는 늘 사랑과 우정이 있었다.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x19288F524C0>

# %%
image_path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행01.jpg'
result, attention_plot = cp.evaluate(image_path)
result = ' '.join(result[:-1])
sequence = kgb.generate_text(result, 72)
sequence = sequence.split(f'{result}, ')[1]
sequence = kgb.spell_check(sequence)
sequence = sequence.replace('   ', ' ')
sequence = sequence.replace('  ', ' ')
sequence = sequence.replace('. ', '.. ')
sequence = ' '.join(sequence.split('. ')[:-1])
sequence = kgb.spell_check(sequence)
sequence
# Out:
# '교수 및 연구자들, 평범한 회사 사람들 이렇게 많은 사람들이 우리와 같은 고민을 하며 살아간다. 사람들은 현재 자기의 경제활동을 하고 있고 정규직으로 일자리도 공평하게 고용하고 있다. 지금 당장 내 앞에 놓인 현실의 불안은 취업난과 출산휴가 등의 고민거리뿐이다.'

# %%
image_path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행01.jpg'
result, attention_plot = cp.evaluate(image_path)
result = ' '.join(result[:-1])
sequence_list = []
for _ in range(3):
    sequence = kgb.result_sequence(result, 72)
    sequence_list.append(sequence)
print(' '.join(sequence_list))
Image.open(image_path)
# Out:
# 순댓국 국물 먹었다 등을 이야기하면서 우리 동네에 대한 시시콜콜한 이야기를 하기 시작했다. 과거의 내 인생이 너무 건조해져 버린 것 같아 아쉽다.  혹시나 누군가가 나에게 괜찮아질 거라고 이야기하면, 그땐 울지 마시고 들어주렴. 순대와 찌개의 어묵탕을 시켰던 일, 왕만두까지 먹었던 추억이 있다. 평소 같으면 젓가락으로 쏟아내렸을 인생은 조금은 알 것 같다. 십 년 전 외 할아버지는 집 안쪽에 늘 계셨다. 그만큼 어머니의 자존심이 강하으신 것이다. 방에 들어가자마자 하는 필사와 온갖 주방에 붙여 넣은 손거울 장난감들이 나의 하루를 1시간 30분을 메꾸었다. 일하는 내 모습을 돌아본다.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x19289039F40>
