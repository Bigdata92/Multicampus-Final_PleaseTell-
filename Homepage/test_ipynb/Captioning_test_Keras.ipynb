# %%
# 하위 폴더에서 상위폴더의 파이썬 파일을 불러 사용하기 위해 필요한 파일
import sys, os
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('Captioning_test_Keras.py'))))

import Captioning_Keras as cp
from PIL import Image

# %%
result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행02.jpg')

# %%
print(' '.join(result[:-1]))
Image.open('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/여행02.jpg')
# Out:
# 한 남자가 공원을 걸어가고 있었다
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1FDAFB90A30>
