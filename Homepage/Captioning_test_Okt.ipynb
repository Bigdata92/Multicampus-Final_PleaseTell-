# %%
import Captioning_Okt as cp
from PIL import Image

# %%
result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/1.jpg')
print(' '.join(result[:-1]))
Image.open('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/1.jpg')
# Out:
# 뒤 에 빈 도시 거리 를 따라 전진한 다
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x341 at 0x11E59FBE220>

# %%
for i in range(5):
    result, attention_plot = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/1.jpg')
    globals()['result' + f'{i}'] = ' '.join(result[:-1])

# %%
for i in range(1, 6):
    caption, _ = cp.evaluate('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/test_images/1.jpg')
    caption = spell_checker.check(' '.join(caption[:-1]))
    globals()['caption_' + f'{i}'] = caption.checked

# %%
from hanspell import spell_checker

result = spell_checker.check(' '.join(result[:-1]))
checked_sequence = result.checked
checked_sequence
# Out:
# '안내소 옆에 앉아 있는 다른 차 들 이 한 대 백화점 전면의 근접 촬영'
