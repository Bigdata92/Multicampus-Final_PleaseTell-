# %% [markdown]
# # naver clova api connection test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import requests
import json

client_id = "kpuxtihwlw"
client_secret = "yiIlfPVRazVErDyLqNOs7lzTe2iiOMsViHfzytNG"

url = "https://naveropenapi.apigw.ntruss.com/vision-obj/v1/detect" # 객체 인식
img = '/content/drive/MyDrive/girl2.jpg'
files = {'image': open(img, 'rb')} # YOUR_FILE_NAME
headers = {'X-NCP-APIGW-API-KEY-ID': client_id, 'X-NCP-APIGW-API-KEY': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print(response.text) # str
else:
    print("Error Code:" + str(rescode))
# Out:
# {"predictions": [{"num_detections": 3, "detection_classes": [1.0, 31.0, 1.0], "detection_names": ["person", "handbag", "person"], "detection_scores": [0.997374, 0.450177, 0.392184], "detection_boxes": [[0.487445, 0.260473, 0.77121, 0.749634], [0.614158, 0.722357, 0.712368, 0.797357], [0.624905, 0.251463, 0.743285, 0.343103]]}]}

# %%
res = json.loads(response.text.encode('utf8')) # dict
print(res)
print(res['predictions'][0]['detection_boxes'])

# with open(out_file, 'w', encoding='utf-8') as outfile:
#     json.dump(res, outfile, indent=4, ensure_ascii=False)
# Out:
# {'predictions': [{'num_detections': 3, 'detection_classes': [1.0, 31.0, 1.0], 'detection_names': ['person', 'handbag', 'person'], 'detection_scores': [0.997374, 0.450177, 0.392184], 'detection_boxes': [[0.487445, 0.260473, 0.77121, 0.749634], [0.614158, 0.722357, 0.712368, 0.797357], [0.624905, 0.251463, 0.743285, 0.343103]]}]}
# [[0.487445, 0.260473, 0.77121, 0.749634], [0.614158, 0.722357, 0.712368, 0.797357], [0.624905, 0.251463, 0.743285, 0.343103]]

# %%
print(res['predictions'][0]['detection_boxes'][0])
print(res['predictions'][0]['detection_boxes'][1])
print(res['predictions'][0]['detection_boxes'][2])
# Out:
# [0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.77121, 0.749634, 0.487445, 0.260473, 0.
# ...
