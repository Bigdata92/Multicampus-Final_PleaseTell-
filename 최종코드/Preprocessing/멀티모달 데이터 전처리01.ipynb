# %%
import os
import json

# %%
import json # 체크포인트를 로드하여 작업시 필요한 수치들 저장
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
path_part = path + os.listdir(path)[0] + '/'
path_part_dt01 = path_part + os.listdir(path_part)[0] + '/'
os.listdir(path_part_dt01)
# Out:
# ['KETI_MULTIMODAL_0000000012',
#  'KETI_MULTIMODAL_0000000012_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_jiyu.json',
#  'KETI_MULTIMODAL_0000000012_jiyu_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234_interpolation.json']

# %%
with open(path_part_dt01 + os.listdir(path_part_dt01)[1], 'r', encoding = 'utf8') as f:
    json_data = json.load(f)
json_data['shot_infos'][0]

# %%
# 경로추출을 통한 영상 및 중복사진 제거
from tqdm.notebook import tqdm

video_list = []
photo_list = []
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
for t in tqdm(range(len(os.listdir(path)))):
    path_part = path + os.listdir(path)[t] + '/'
    for i in range(len(os.listdir(path_part))):
        path_part_dt01 = path_part + os.listdir(path_part)[i] + '/'
        for k in range(len(os.listdir(path_part_dt01))): 
            if 'mp4' in os.listdir(path_part_dt01)[k]:
                video =  path_part_dt01 + os.listdir(path_part_dt01)[k]
                video_list.append(video)
        for folder_name in os.listdir(path_part_dt01):
            if '.' not in folder_name:
                path_part_dt02 = path_part_dt01 + folder_name + '/'
        for folder_name in os.listdir(path_part_dt02):
            if '.' not in folder_name:
                path_part_dt03 = path_part_dt02 + folder_name + '/'
                for photo in os.listdir(path_part_dt03)[1:]:
                    photo_name = path_part_dt03 + photo
                    photo_list.append(photo_name)   
                    
# 필요없는 영상 및 중복사진 삭제
for video in tqdm(video_list):
    os.remove(video)
for photo in tqdm(photo_list):
    os.remove(photo)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
# 이미지 경로 추출
from tqdm.notebook import tqdm
photo_list = []
photo_dir_list = []
photo_folderName_list = []
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
for t in tqdm(range(len(os.listdir(path)))):
    path_part = path + os.listdir(path)[t] + '/'
    for i in range(len(os.listdir(path_part))):
        path_part_dt01 = path_part + os.listdir(path_part)[i] + '/'
        for folder_name in os.listdir(path_part_dt01):
            if '.' not in folder_name:
                path_part_dt02 = path_part_dt01 + folder_name + '/'
        for folder_name in os.listdir(path_part_dt02):
            if '.' not in folder_name:
                photo_folderName_list.append(folder_name)
                path_part_dt03 = path_part_dt02 + folder_name + '/'
                for photo in os.listdir(path_part_dt03):
                    photo_dir = path_part_dt03 + photo
                    photo_list.append(photo)
                    photo_dir_list.append(photo_dir)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
import pandas as pd
df = pd.DataFrame({'사진경로(전체경로)' : photo_dir_list, '사진이름' : photo_list})
df['사진경로(이미지폴더)'] = [0 for _ in range(len(photo_dir_list))]

# %%
len(photo_dir_list), len(photo_list), len(photo_folderName_list)
# Out:
# (24191, 24191, 24198)

# %%
# for photo_folderName in tqdm(photo_folderName_list):
#     for i in range(len(photo_dir_list)):
#         if photo_folderName in df['사진경로(전체경로)'][i]:
#             df['사진경로(이미지폴더)'][i] = photo_folderName
# Out:
#   0%|          | 0/24198 [00:00<?, ?it/s]

# %%
n = 5500
df['사진경로(전체경로)'][n], df['사진경로(이미지폴더)'][n] 
df.to_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(작성중1).csv', index = False)

# %%
df = pd.read_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(작성중1).csv')
df.head()
# Out:
#                                           사진경로(전체경로)               사진이름  \
# 0  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  KM_0000000009.jpg
# 1  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  KM_0000000041.jpg
# 2  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  KM_0000000092.jpg
# 3  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  KM_0000000172.jpg
# 4  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  KM_0000000213.jpg
#
#             사진경로(이미지폴더)
# 0  KETI_SHOT_0000145747
# 1  KETI_SHOT_0000145748
# 2  KETI_SHOT_0000145749
# 3  KETI_SHOT_0000145750
# 4  KETI_SHOT_0000145751

# %%
# 불필요 json파일 제거
from tqdm.notebook import tqdm

json_list = []
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
for t in tqdm(range(len(os.listdir(path)))):
    path_part = path + os.listdir(path)[t] + '/'
    for i in range(len(os.listdir(path_part))):
        path_part_dt01 = path_part + os.listdir(path_part)[i] + '/'
        for json_file in os.listdir(path_part_dt01):
            if '.' not in json_file:
                json_file_N = json_file
        for json_file in os.listdir(path_part_dt01):
            if json_file != json_file_N and json_file != json_file_N + '_interpolation.json':
                json_list.append(path_part_dt01 + json_file)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
len(set(json_list)), len(json_list)
# Out:
# (7196, 7196)

# %%
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
path_part = path + os.listdir(path)[0] + '/'
path_part_dt01 = path_part + os.listdir(path_part)[0] + '/'

with open(path_part_dt01 + os.listdir(path_part_dt01)[1], 'r', encoding = 'utf8') as f:
    json_data = json.load(f)
print(len(json_data['shot_infos'][0]))
print(json_data['shot_infos'][0]['image_folder']) # 이미지 사진이 저장된 폴더 이름
print(len(json_data['shot_infos'][0]['visual_infos'])) 
print(json_data['shot_infos'][0]['visual_infos'][0]['image_id']) # 이미지 파일이름
print(json_data['shot_infos'][0]['visual_infos'][0]['image_descs']) # 캡셔닝 데이터
json_data['shot_infos'][1]['image_folder']
os.listdir(path_part_dt01)
# Out:
# 2
# KETI_SHOT_0000145756
# 53
# KM_0000000448.jpg
# ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남자는 흰 셔츠를 입고있다', '남자는 옆을 보고있다']
# ['KETI_MULTIMODAL_0000000012',
#  'KETI_MULTIMODAL_0000000012_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_jiyu.json',
#  'KETI_MULTIMODAL_0000000012_jiyu_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234_interpolation.json']

# %%
df = pd.read_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(작성중1).csv')
df['캡셔닝_데이터'] = [0 for _ in range(len(df['사진이름']))]
df['사진경로(전체경로)'][0]
# Out:
# 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/멀티모달_Part_01/KETI_MULTIMODAL_0000000012/KETI_MULTIMODAL_0000000012/KETI_SHOT_0000145747/KM_0000000009.jpg'

# %%
# 사진별 캡셔닝 데이터 추출 및 데이터 프레임에 저장
from tqdm.notebook import tqdm

caption_list = []
image_name_list = []
path = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/'
for t in tqdm(range(len(os.listdir(path)))):
    path_part = path + os.listdir(path)[t] + '/'
    for i in range(len(os.listdir(path_part))):
        path_part_dt01 = path_part + os.listdir(path_part)[i] + '/'
        for json_file in os.listdir(path_part_dt01):
            if '.' not in json_file:
                json_file_N = json_file
        json_file = path_part_dt01 + json_file_N + '_interpolation.json'
        try:
            with open(json_file, 'r', encoding = 'utf8') as f: 
                json_data = json.load(f)
            for num1 in range(len(json_data['shot_infos'])):
                for num2 in range(len(df['사진경로(전체경로)'])):
                    if json_data['shot_infos'][num1]['image_folder'] == df['사진경로(이미지폴더)'][num2]:
                        for num3 in range(len(json_data['shot_infos'][num1]['visual_infos'])):
                            if json_data['shot_infos'][num1]['visual_infos'][num3]['image_id'] == df['사진이름'][num2]:
                                df['캡셔닝_데이터'][num2] = json_data['shot_infos'][num1]['visual_infos'][num3]['image_descs']
                                caption_list.append(json_data['shot_infos'][num1]['visual_infos'][num3]['image_descs'])
                                image_name_list.append(df['사진경로(전체경로)'][num2])
        except:
            print(json_file)
# 프린트 되는 json파일은 오류가 뜬것입니다.....
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
# 방법1 : json에서 추출실패한 181개 값 삭제처리
list1 = [] 
for i in range(len(df[df['캡셔닝_데이터'] == 0]['사진경로(전체경로)'])):
    list1.append(list(df[df['캡셔닝_데이터'] == 0]['사진경로(전체경로)'])[i][90:129])
len(list1), len(list1)
# Out:
# (181, 181)

# %%
df_ch = df[df['캡셔닝_데이터'] != 0].copy()
df_ch.reset_index(drop = True, inplace = True)
df_ch.columns = ['사진경로', '사진이름', '사진폴더이름', '캡셔닝_데이터(종합)']

# %%
len(df), len(df_ch), (len(df) - len(df_ch))
# Out:
# (24191, 24010, 181)

# %%
# 방법2 : 추출할때 해당하는 이미지만 따로 추출하여 리스트로 변환후 df통합
print(len(caption_list), len(image_name_list))
n = 0
for i in range(len(caption_list)):
    for k in range(len(caption_list[i])):
        n += 1

df_ch_an = pd.DataFrame({'사진경로' : [0 for _ in range(n)], '캡셔닝_데이터' : [0 for _ in range(n)]})

n = 0
for i in range(len(image_name_list)):
    for k in range(len(caption_list[i])):
        df_ch_an['사진경로'][n] = image_name_list[i]
        df_ch_an['캡셔닝_데이터'][n] = caption_list[i][k]
        n += 1
df_ch_an
# Out:
# 24010 24010
# <ipython-input-503-e2f0068b399d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ch_an['캡셔닝_데이터'][n] = caption_list[i][k]
# C:\Users\Bestc\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                                      사진경로           캡셔닝_데이터
# 0       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...           남자들이 있다
# 1       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...    남자들은 서로 쳐다보고있다
# 2       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...        남자는 검정머리이다
# 3       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...    남자는 흰 셔츠를 입고있다
# 4       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...       남자는 옆을 보고있다
# ...                                                   ...               ...
# 120040  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     여자가 앞쪽을 보고 있다
# 120041  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     여자는 입을 다물고 있다
# 120042  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...       여자는 외투를 입었다
# 120043  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  여자의 외투에는 털이 달려있다
# 120044  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...        여자는 야외에 있다
#
# [120045 rows x 2 columns]

# %%
df_ch_an = pd.merge(df_ch_an, df_ch, left_on='사진경로', right_on='사진경로', how='left')
df_ch_an.head()
# Out:
#                                                 사진경로         캡셔닝_데이터  \
# 0  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...         남자들이 있다
# 1  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  남자들은 서로 쳐다보고있다
# 2  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...      남자는 검정머리이다
# 3  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  남자는 흰 셔츠를 입고있다
# 4  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     남자는 옆을 보고있다
#
#                 사진이름                사진폴더이름  \
# 0  KM_0000000448.jpg  KETI_SHOT_0000145756
# 1  KM_0000000448.jpg  KETI_SHOT_0000145756
# 2  KM_0000000448.jpg  KETI_SHOT_0000145756
# 3  KM_0000000448.jpg  KETI_SHOT_0000145756
# 4  KM_0000000448.jpg  KETI_SHOT_0000145756
#
#                                          캡셔닝_데이터(종합)
# 0  [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 1  [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 2  [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 3  [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 4  [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...

# %%
from PIL import Image
n = 5500
print(df_ch_an['캡셔닝_데이터'][n])
Image.open(df_ch_an['사진경로'][n])
# Out:
# 남자1이 웃고 있다.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x201B90152E0>

# %%
# 캡셔닝 데이터가 없는 데이터 추가제거 - 146개
df_ch_an1 = df_ch_an[df_ch_an['캡셔닝_데이터'] != ''].copy()
df_ch_an1.reset_index(drop = True, inplace = True)
df_ch_an1
# Out:
#                                                      사진경로           캡셔닝_데이터  \
# 0       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...           남자들이 있다
# 1       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...    남자들은 서로 쳐다보고있다
# 2       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...        남자는 검정머리이다
# 3       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...    남자는 흰 셔츠를 입고있다
# 4       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...       남자는 옆을 보고있다
# ...                                                   ...               ...
# 119894  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     여자가 앞쪽을 보고 있다
# 119895  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     여자는 입을 다물고 있다
# 119896  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...       여자는 외투를 입었다
# 119897  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  여자의 외투에는 털이 달려있다
# 119898  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...        여자는 야외에 있다
#
#                      사진이름                사진폴더이름  \
# 0       KM_0000000448.jpg  KETI_SHOT_0000145756
# 1       KM_0000000448.jpg  KETI_SHOT_0000145756
# 2       KM_0000000448.jpg  KETI_SHOT_0000145756
# 3       KM_0000000448.jpg  KETI_SHOT_0000145756
# 4       KM_0000000448.jpg  KETI_SHOT_0000145756
# ...                   ...                   ...
# 119894  KM_0000004318.jpg  KETI_SHOT_0000148199
# 119895  KM_0000004318.jpg  KETI_SHOT_0000148199
# 119896  KM_0000004318.jpg  KETI_SHOT_0000148199
# 119897  KM_0000004318.jpg  KETI_SHOT_0000148199
# 119898  KM_0000004318.jpg  KETI_SHOT_0000148199
#
#                                               캡셔닝_데이터(종합)
# 0       [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 1       [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 2       [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 3       [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# 4       [남자들이 있다, 남자들은 서로 쳐다보고있다, 남자는 검정머리이다, 남자는 흰 셔츠...
# ...                                                   ...
# 119894  [여자가 앞쪽을 보고 있다, 여자는 입을 다물고 있다, 여자는 외투를 입었다, 여자...
# 119895  [여자가 앞쪽을 보고 있다, 여자는 입을 다물고 있다, 여자는 외투를 입었다, 여자...
# 119896  [여자가 앞쪽을 보고 있다, 여자는 입을 다물고 있다, 여자는 외투를 입었다, 여자...
# 119897  [여자가 앞쪽을 보고 있다, 여자는 입을 다물고 있다, 여자는 외투를 입었다, 여자...
# 119898  [여자가 앞쪽을 보고 있다, 여자는 입을 다물고 있다, 여자는 외투를 입었다, 여자...
#
# [119899 rows x 5 columns]

# %%
df_ch_an1.to_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(작성중2).csv', index = False)
df_ch_an1 = pd.read_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(작성중2).csv')
df_ch_an1.head()
# Out:
#                                                 사진경로         캡셔닝_데이터  \
# 0  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...         남자들이 있다
# 1  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  남자들은 서로 쳐다보고있다
# 2  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...      남자는 검정머리이다
# 3  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...  남자는 흰 셔츠를 입고있다
# 4  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...     남자는 옆을 보고있다
#
#                 사진이름                사진폴더이름  \
# 0  KM_0000000448.jpg  KETI_SHOT_0000145756
# 1  KM_0000000448.jpg  KETI_SHOT_0000145756
# 2  KM_0000000448.jpg  KETI_SHOT_0000145756
# 3  KM_0000000448.jpg  KETI_SHOT_0000145756
# 4  KM_0000000448.jpg  KETI_SHOT_0000145756
#
#                                          캡셔닝_데이터(종합)
# 0  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 1  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 2  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 3  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 4  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...

# %%
check_point = 'Part_01' # Part_01 ~ 11까지 구분(기존 파일 폴더명)
df_ch['사진경로'][0]
# Out:
# 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달/멀티모달_분야/멀티모달_Part_01/KETI_MULTIMODAL_0000000012/KETI_MULTIMODAL_0000000012/KETI_SHOT_0000145747/KM_0000000009.jpg'

# %%
import shutil
image_path_bf = df_ch['사진경로'][0]
image_path_af = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달(자료통합)'
shutil.copy2(image_path_bf,image_path_af)
# Out:
# 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달(자료통합)\\KM_0000000009.jpg'

# %%
os.rename(image_path_af + '/' + df_ch['사진이름'][0], image_path_af + '/' + df_ch['사진폴더이름'][0] + '_' + df_ch['사진이름'][0])

# %%
import shutil
image_path_af = 'C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달 데이터/멀티모달(자료통합)'
for i in tqdm(range(len(df_ch['사진경로']))):
    image_path_bf = df_ch['사진경로'][i]
    shutil.copy2(image_path_bf, image_path_af)
    os.rename(image_path_af + '/' + df_ch['사진이름'][i], image_path_af + '/' + df_ch['사진폴더이름'][i] + '_' + df_ch['사진이름'][i])
# Out:
#   0%|          | 0/24010 [00:00<?, ?it/s]

# %%
df_ch_an2 = df_ch_an1[['사진경로', '사진이름' ,'캡셔닝_데이터(종합)', '캡셔닝_데이터']].copy() 
df_ch_an2['사진이름'] = df_ch_an1['사진폴더이름'] + '_' + df_ch_an1['사진이름']
df_ch_an2['사진경로'] = image_path_af + '/' + df_ch_an2['사진이름']
df_ch_an2.head()
# Out:
#                                                 사진경로  \
# 0  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 1  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 2  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 3  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 4  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
#
#                                      사진이름  \
# 0  KETI_SHOT_0000145756_KM_0000000448.jpg
# 1  KETI_SHOT_0000145756_KM_0000000448.jpg
# 2  KETI_SHOT_0000145756_KM_0000000448.jpg
# 3  KETI_SHOT_0000145756_KM_0000000448.jpg
# 4  KETI_SHOT_0000145756_KM_0000000448.jpg
#
#                                          캡셔닝_데이터(종합)         캡셔닝_데이터
# 0  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...         남자들이 있다
# 1  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...  남자들은 서로 쳐다보고있다
# 2  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...      남자는 검정머리이다
# 3  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...  남자는 흰 셔츠를 입고있다
# 4  ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...     남자는 옆을 보고있다

# %%
for index, caption in enumerate(df_ch_an2['캡셔닝_데이터']):
    if '다' not in caption:
        print(caption, index)
# Out:
# 여자가 보라색 옷을 입고있따 563
# 여자가 보라색 셔츠를 입고있따 642
# 남자와 여자는 핑크색 옷을 입었 740
# 여자가 깃이 넓은 셔츠를 입고 있따 3679
# 여자가 깃이 넓은 셔츠를 입고 있따 3704
# 여자가 깃이 넓은 셔츠를 입고 있따 3714
# 여자가 깃이 넓은 셔츠를 입고 있따 3724
# 여자가 깃이 넓은 셔츠를 입고 있따 3734
# 여자가 머리를 4041
# 여자2가 웃고 있따 4208
# 여자가 무언가를 말하는 것 같가 7844
# 남자 한 명이 넥타이를 메고 있따 8408
# 남자 머리는 노란색이 섞여있따 9343
# 남자 한 명이 넥타이를 하고 있따 10601
# 여자가 레이스 원피스를 입고 있디. 10761
# 사람들이 길 위에 있따 11240
# 남자는 눈을 아래로 깔고 있ㄷ 13603
# 여자 앞쪽에 촛불이 있따 13795
# 사람이 휴대전화를 들고 있따 14984
# 머리를  16012
# 남자는 안대를 쓰고 있따 16465
# 두 명의 여자가 가게에 있따 17671
# 여자가 어쩔줄 몰라하고 있따. 19416
# 남자가 바닥을 바라보고 이싿. 19438
# 남자가 고개를 돌렸따 19454
# 남자가 빨간옷을 입고있따 20090
# 사람이 갈색 단화를 신고있따 20329
# 여자가 눈을 뜨고 있따  23910
# 입을 벌린 남성  24139
# 표정이 어두운 남성 24140
# 검은 상의를 입은 남성  24141
# 머리를 띄어 올린 남성  24142
# 눈매가 매서운 남성  24143
# 쇼파에 앉아있는 남성   24144
# 책들이 널부러져 있음 24145
# 집에서 앉아있는 남성  24146
# 스웨터를 입고있는 남성  24147
# 머리를 올린 남성  24148
# 여자가 고개를 돌려 남자를 바라보낟. 25288
# 남자가 바가지머리를 하고 있따 26086
# 남자는 턱에 반창고를 붙였따 26351
# 남자1의 턱에 무언가 붙어있따 26548
# 남자의 눈동자가 위로가있따 26567
# 남자가 회색 옷을 입고 있따 26936
# 여자가 붉은색 겉옷을 입고있따 27547
# 여자가 체크무늬 옷을 입고있따 28188
# 남자가 카키색 옷을 입고있디 28227
# 여자가 체크무늬 옷을 입고있따 28327
# 사람이 봉투에서 무언가 꺼내고 있따 28357
# 여자1은 흰색 니트를 입고있 31236
# 남자가 손에 무언가 들고 있따 31773
# 여자가 황토색 옷을 입고 있따 31857
# 여자가 황토색 옷을 입고있따 31906
# 셔츠를 입고있는 남성 32429
# 안타까워하는 남성 32430
# 슬퍼보이는 남성 32431
# 셔츠를 풀어헤친 남성 32432
# 입을 모은 남성 32433
# 넋이 나간듯한 남성 32434
# 스웨터를 입은 남성 32435
# 입을 벌린 남성 32436
# 머리가 헝클어진 남성 32437
# 허공을 응시하는 남성 32438
# 셔츠를 입고있는 남성1 32439
# 안타까워하는 표정의 남성1 32440
# 머리가 단정한 남성1 32441
# 가르마를 탄 남성1 32442
# 미간의 주름이 잡힌 남성1  32443
# 스웨터를 입은 남성  32444
# 자리를 박차고 나가는 남성 32445
# 머리가 헝클어진 남성 32446
# 급하게 나가려는 남성 32447
# 일어서는 남성 32448
# 셔츠를 입고있는 남성1 32449
# 얼굴을 찡그린 남성 32450
# 슬퍼보이는 남성1 32451
# 셔츠를 풀어헤친 남성1 32452
# 남성2를 붙잡는 남성1 32453
# 셔츠를 입은 남성1 32454
# 급히 일어나는 남성2 32455
# 우울해 보이는 남성1 32456
# 침대를 박차고 일어나려는 남성2 32457
# 머리가 헝클어진 남성2 32458
# 스웨터를 입은 남성  32459
# 우울한듯한 표정의 남성 32460
# 머리가 헝클어진 남성 32461
# 슬픈표정의 남성 32462
# 허공을 응시하는 남성 32463
# 남자2는 초록색 정장을 입었따 32911
# 남자들여럿이 서있디 32912
# 남자들이 정장을 입고 서있따. 32939
# 남자2는 초록색정장을 입었따. 33125
# 여자1의 코에 휴지가 꼽혀있따 33199
# 베이지색 자켓을 입은 남성 34044
# 머리가 단정한 남성 34045
# 무언가를 보는 남성 34046
# 가르마를 탄 남성  34047
# 감정이 북받친듯한 남성 34048
# 베이지색 자켓을 입은 남성 34049
# 머리가 단정한 남성  34050
# 무언가를 보는 남성  34051
# 가르마를 탄 남성  34052
# 감동받은 남성 34053
# 베이지색 자켓을 입은 남성 34054
# 머리가 단정한 남성  34055
# 무언가를 보는 남성  34056
# 가르마를 탄 남성  34057
# 감정이 북받친듯한 남성 34058
# 스웨터를 입은 남성  34059
# 머리가 단정한 남성  34060
# 무언가를 보는 남성  34061
# 가르마를 탄 남성  34062
# 감동받은 남성 34063
# 스웨터를 입은 남성  34064
# 머리가 단정한 남성  34065
# 무언가를 보는 남성  34066
# 가르마를 탄 남성  34067
# 감동받은 남성 34068
# 스웨터를 입은 남성  34069
# 머리가 단정한 남성  34070
# 무언가를 보는 남성  34071
# 가르마를 탄 남성  34072
# 감동한듯한 표정의 남성 34073
# 스웨터를 입은 남성  34074
# 머리가 단정한 남성  34075
# 무언가를 보는 남성  34076
# 가르마를 탄 남성  34077
# 스웨터를 입은 남성  34078
# 머리가 단정한 남성  34079
# 앞머리를 정리한 남성  34080
# 가르마를 탄 남성  34081
# 무언가를 읽고있는 남성  34082
# 눈을 가늘게 뜬 남성  34083
# 머리가 단정한 남성  34084
# 앞머리를 정리한 남성  34085
# 옅은 미소를 띈 남성  34086
# 기뻐보이는 남성  34087
# 스웨터를 입은 남성  34088
# 남자가 입을 살짝 벌리고 있따. 34735
# 여자 2가 앉아있따.  35286
# 남자뒤로 자동차가 지나가고있따 35759
# 여자는 흰색 티셔츠를 입었따 35796
# 남자가 눈을 동그랗게 뜨고 있따 35855
# 남자가 하늘색 티셔츠를 입었따.  36260
# 남자는 빨간색 티셔츠를 입었따 38491
# 여자는 연보라색옷을 입고있따 38636
# 유니폼을 입은 여자가 보인자 38660
# 남자3은 넥타이를 맸따 38696
# 사람들이 진정석을 바라보고있따 39380
# 남자가 정장을 입고있따 39404
# 여자2는 하늘색 옷을 입었따 39442
# 남자1은 땡땡이 셔츠를 입었디 39481
# 남자2가 남자1에게 부탁하고있따 39489
# 여자1은 머리에 안경을 썼따 41025
# 남자는 머리에 왁스를 발랐따 41069
# 사무실에 사람들이 모여있따 41084
# undefined 42924
# undefined 42925
# undefined 42926
# undefined 42927
# undefined 42928
# 여자는 머리를 묶었따 43192
# 여자는 눈을 뜨고 있따 43197
# 여자는 웃고 있따 43324
# 여자는 하늘색 블라우스를 입었따 43330
# 여자와 남자가 사무실 안에 있따 43698
# 종이를 든 여성  45769
# 점퍼를 입은 여성  45770
# 후드티를 입은 여성  45771
# 우유곽을 든 여어딘가를 응시하는 여성 성  45772
# 파마를 한 여성  45773
# 우유곽을 든 여성  45775
# 종이를 쥔 여성  45776
# 파마를 한 여성  45777
# 장갑을 낀 여성  45778
# 종이를 읽는 여성  45779
# 해맑게 웃는 여성  45780
# 우유곽을 든 여성  45781
#  종이를 든 여성  45782
# 파마머리를 한 여성  45783
# 파마머리를 한 여성 45784
# 종이를 든 여성  45785
# 우유곽을 든 여성 45786
# 해맑게 웃는 여성  45787
# 종이를 읽는 여성 45788
# 파마머리를 한 여성  45789
# 종이를 든 여성  45790
# 점퍼를 입은 여성  45791
# 후드티를 입은 여성  45792
# 종이를 읽는 여성  45793
# 파마머리를 한 여성  45799
# 종이를 든 여성  45800
# 점퍼를 입은 여성 45801
# 후드티를 입은 여성  45802
# 어딘가를 응시하는 여성  45803
# 서로를 마주보는 두여성  45804
# 종이를 든 한 여성  45805
# 우유팩을 든 한 여성 45806
# 장갑을 낀 한 여성 45807
# 후드티를 입은 한 여성  45808
# 진지한 표정의 여성  45809
# 머리에 삔을 꽂은 여성  45810
# 종이를 읽고 있는 여성 45811
# 후드티를 입고있는 여성 45812
#  긴점퍼를 입고있는 여성  45813
# 고개를 숙인채 쓰레기 더미를 뒤지는 여성   45814
# 검정색 점퍼를 입고있는 여성 45816
# 노란 쓰레기통을 들고있는 여성  45817
# 박스더미를 앞에둔채 서있는 여성  45818
# 쓰레기장에 있는 두여성  45819
# 점퍼를 입은 여성 45820
# 파란색 코트를 입은 여성  45821
# 노란색 상자를 든 여성  45822
# 허리를 숙인 두 여성  45823
# 고개를 숙인채 쓰레기 더미를 뒤지는 여성 45824
# 검정색 점퍼를 입고있는 여성   45826
# 노란 쓰레기통을 들고있는 여성  45827
# 박스더미를 앞에둔채 서있는 여성 45828
# 쓰레기장으로 들어오는 여성  45829
# 바구니를 든 여성  45830
# 빨간신발을 신은 여성  45831
# 회색 점퍼를 입은 여성  45832
# 쓰레기 더미들을 향해 걸어가는 여성  45833
# 여자가 우산을 쓰고 있ㄷ.  46212
# 남자가 넥타이를 하고 있따 47689
# 여자가 맞은 편에 앉은 사람에게 말하 47986
# 남자 뒤쪽에 물건들이 많이 있따 48673
# 여자2는 안경을 썼어 49495
# 남자2는 안에 검정티를 입고 있따  50688
#   52809
# 남자2가 남자1뒤에 서있따 53191
# 남자는 오른손으로 젓가락을 들고 있따 54606
# 남자는 하얀색 셔츠를 입고 있따 54653
# 남자1이 서있따 55154
# 여자는 단발 머릳. 55893
# 남자의 머리카락은 눈썹위에 있따 56007
# 두 남자 모두 안경을 썼따 56618
# 남자1은 반짝거리는 옷을 입고있따. 60411
# 여자2는 앞머리가 없ㄷ. 60493
# 여자1은 하늘색 옷을 입고있따. 60520
# 여자는 하늘색티를 입고있따. 60537
# 남자3은 남자1 앞에있따. 60602
# 여자1은 줄무늬를 입고있따. 60660
# 남자1은 초록색옷을 입고있따. 60741
# 사람들이 짧은 옷을 입고있따 61686
# 남자가 무언가를 말하고 있ㄷ. 67177
# 화이트보드에 종이가 붙어 67792
# 여자1이 종이를 들고 있따. 68232
# 여자가 단발머리를 하고 있ㄷ 70965
# 남자가 턱에 손을대고있 73851
# 방 안에 침대가 놓여있디. 74365
# 여자가 베이지색 바지를 입고있따 75401
# 남자2가 얼굴을 찡그리고있따. 75916
# 남자1은 입꼬리가 올라갔따 76586
# 남자1뒤로 야경이보이나 76613
# 남자 2가 남자1에게 말하고 있따.  76632
# 여자1은 파란색코트를 입었따. 76897
# 남자 2가 남자 1과 남자 3의 머리채를 잡았따.  77800
# 남자 1이 남방을 입었따.  77821
# 남자가 여자와 함께 있ㄷ.  78334
# 2, 0, 0, 0 78559
# 2, 0, 0, 0 78560
# 2, 0, 0, 0 78561
# 2, 0, 0, 0 78562
# 2, 0, 0, 0 78563
# 여자와 남자는 마주보고 앉아있따 78772
# 남자는 목까지 오는 옷을 입었따 78796
# 오른손으로 나이프를 집고있따 79662
# 여자1이 스카프를 매고있디 80864
# 남자가 갈색 겉옷을 이 84563
# 남자가 베이지색 코트를 입고 있따. 86142
# 여자가 사무실에 있자 87330
# 여자의 뒤로 블라인드가 쳐져 있따. 88174
# 남자1은 청록색 옷을 입고있따. 88411
# 여자가 줄무늬 옷을 입고 90020
# 남자2는 검정넥타이를 했따 93247
# 여자가 초록색 가디건을 입고있따 95097
# 남자들은 사무실안에있따 98331
# 남자3이 검은  99708
# 남자2는 넥타이를 맸따 99736
# 회색바지를 입었따 99746
# 남자들이 계단에 있따 99759
# 남자들이 남자1을 달래고있따 99826
# 사람이 남자쪽으로 고개를 숙이고 있따 106155
# 노란머리 여자가 남자의 팔을 잡고 있따 106710
# 남자는 입을 조금 벌리고 있따 107565
# 여자는 외투를 입었따 107592
# 표정이 굳은 남성  107719
# 서로를 마주보는 두 남성  107720
# 음식점에 있는 남성 107721
# 인상을 쓰는 남성  107722
# 양복을 입은 남성  107723
# 표정이 굳은 남성  107724
# 어두운 표정의 남성  107725
# 음식점에 있는 남성 107726
# 걱정스런 표정의 남성  107727
#  양복을 입은 남성  107728
# 양복을 입은 남성  107729
# 상대방을 노려보는 남성  107730
#  음식점에 있는 남성 107731
# 어두운 표정의 남성  107732
# 표정이 굳은 남성  107733
# 인상을 쓰고있는 남성  107734
# 상대방을 노려보는 남성  107735
# 음식점에 있는 남성 107736
# 표정이 굳은 남성  107737
#  걱정스런 눈빛에 남성  107738
#  인상을 쓰고있는 남성 107739
# 상대방을 노려보는 남성  107740
# 음식점에 있는 남성 107741
# 양복을 입은 남성 107742
# 걱정스런 눈빛에 남성  107743
# 인상을 쓰고있는 남성  107744
# 상대방을 노려보는 남성  107745
# 음식점에 있는 남성  107746
# 양복을 입은 남성  107747
# 걱정스런 눈빛에 남성   107748
# 젓가락을 쥔 남성  107754
# 넥타이를 맨 남성  107755
# 밥먹을 준비를 하는 남성  107756
# 서로 마주보고 있는 두남성  107757
# 물잔을 옆에 두고 있는 남성  107758
# 초점이 풀린 남성  107759
# 무표정을 하고 있는 남성  107760
# 음식점에 온 남성  107761
# 양복을 입은 남성  107762
# 음식을 먹을 준비를 하는 남성  107763
# 젓가락질을 하는 남성  107764
# 음식점에 온 두남성 107765
# 양복을 입은 두남성  107766
# 서로를 마주보고 앉은 두남성  107767
# 먹을 준비를 하는 두남성  107768
# 서로를 마주보고 앉은 두남성  107769
# 먹을 준비를 하는 두남성  107770
# 음식점에 온 두남성  107771
# 양복을 입은 두남성  107772
# 넥타이를 푼 남성  107773
# 서로를 마주보고 앉은 두남성  107774
# 젓가락질을 하는 남성  107775
# 먹을 준비를 하는 두남성  107776
# 음식점에 온 두남성  107777
# 양복을 입은 두남성 107778
# 양복을 입은 두남성  107779
# 음식점에 온 두남성  107780
# 넥타이를 풀은 남성  107781
# 먹을 준비를 하는 두남성  107783
# 양복을 입은 두남성  107784
# 음식점에 온 두남성  107785
# 먹을 준비를 하는 두남성  107786
# 젓가락질을 하는 남성  107787
# 서로를 마주보고 앉은 두남성  107788
# 서로를 마주보는 두남성  107789
# 음식이 식탁에 올려져 있음 107790
# 먹을 준비를 하는 두남성  107791
# 익어가는 감자탕이 남성들 사이에 있음  107792
#  양복을 입은 두남성  107793
# 양복을 입은 두남성  107794
#  익어가는 감자탕이 남성들 사이에 있음  107795
# 먹을 준비를 하는 두남성  107796
# 음식이 식탁에 올려져 있음 107797
# 서로를 마주보는 두남성 107798
# 양복을 입은 두남성  107799
# 익어가는 감자탕이 남성들 사이에 있음  107800
# 먹을 준비를 하는 두남성  107801
# 음식이 식탁에 올려져 있음 107802
# 서로를 마주보는 두남성  107803
# 음식을 입에 넣으려하는 남성  107809
# 입을 벌리고 있는 남성  107810
# 뜨거운 김이 올라오는 음식을 먹는 남성  107811
# 양복을 입은 남성  107812
# 음식점에 온 남성  107813
# 음식을 먹고있는 남성  107814
# 넥타이를 맨 남성  107815
# 음식점에 온 남성  107816
# 인상을 쓰는 남성  107817
# 맛을 음미하는 남성  107818
# 여자1이 고개를 돌리고 있따 109775
# 여자가 점박이무늬 옷을 입었따 110688
# 남자는 입을 벌리고 있따 112086
# 남자는 주황색 줄이 있는 옷을 입었따 114258
# 여자2는 팔찌를 하고 있디. 116513
# 뒤에 문이 있따 119735
# 여자의 외투에는 털이 달려있따  119838

# %%
# 맞춤법 틀린 캡셔닝 수정
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('. ', '.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('있따', '있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('입었따', '입었다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('있디', '있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('입었', '입었다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('같가', '같다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('있ㄷ', '있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('이싿', '있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('입고있', '입고있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('돌렸따', '돌렸다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('바라보낟.', '바라본다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('붙였따.', '붙였다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('보인자.', '보인다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('보인자.', '보인다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('맸따', '맸다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('썼따', '썼다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('발랐따', '발랐다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('묶었따', '묶었다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('없ㄷ', '없다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('올라갔따', '올라갔다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('종이가 붙어', '종이가 붙어있다'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('손을대고있', '손을 대고있다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('올라갔따', '올라갔다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('야경이보이나', '야경이보인다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('잡았따.', '잡았다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('있자', '있다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('했따', '했다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('두남성', '두 남성'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('사람에게 말하', '사람에게 말하고 있다.'))
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: x.replace('썼어', '썼다.'))

# 잘못작성된 캡셔닝 삭제
df_ch_an2.drop([4041, 16012, 42924, 42925, 42926, 42926, 42927, 42928, 45772, 52809, 84563, 90020, 99708, 107738, 107748, 78550, \
                78551, 78552, 78553, 78554, 55884], inplace = True)
df_ch_an2.reset_index(drop = True, inplace = True)
df_ch_an2

import re
df_ch_an2['캡셔닝_데이터'] = df_ch_an2['캡셔닝_데이터'].apply(lambda x: re.sub('[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z0-9, ]', '', x))

# %%
for index, caption in enumerate(df_ch_an2['캡셔닝_데이터']):
    if '다' not in caption:
        print(caption, index)
# Out:
# 입을 벌린 남성  24133
# 표정이 어두운 남성 24134
# 검은 상의를 입은 남성  24135
# 머리를 띄어 올린 남성  24136
# 눈매가 매서운 남성  24137
# 쇼파에 앉아있는 남성   24138
# 책들이 널부러져 있음 24139
# 집에서 앉아있는 남성  24140
# 머리를 올린 남성  24142
# 남자는 턱에 반창고를 붙였따 26345
# 안타까워하는 남성 32424
# 슬퍼보이는 남성 32425
# 셔츠를 풀어헤친 남성 32426
# 입을 모은 남성 32427
# 넋이 나간듯한 남성 32428
# 스웨터를 입은 남성 32429
# 입을 벌린 남성 32430
# 머리가 헝클어진 남성 32431
# 허공을 응시하는 남성 32432
# 안타까워하는 표정의 남성1 32434
# 머리가 단정한 남성1 32435
# 가르마를 탄 남성1 32436
# 미간의 주름이 잡힌 남성1  32437
# 스웨터를 입은 남성  32438
# 자리를 박차고 나가는 남성 32439
# 머리가 헝클어진 남성 32440
# 급하게 나가려는 남성 32441
# 일어서는 남성 32442
# 얼굴을 찡그린 남성 32444
# 슬퍼보이는 남성1 32445
# 셔츠를 풀어헤친 남성1 32446
# 남성2를 붙잡는 남성1 32447
# 셔츠를 입은 남성1 32448
# 급히 일어나는 남성2 32449
# 우울해 보이는 남성1 32450
# 침대를 박차고 일어나려는 남성2 32451
# 머리가 헝클어진 남성2 32452
# 스웨터를 입은 남성  32453
# 우울한듯한 표정의 남성 32454
# 머리가 헝클어진 남성 32455
# 슬픈표정의 남성 32456
# 허공을 응시하는 남성 32457
# 베이지색 자켓을 입은 남성 34038
# 머리가 단정한 남성 34039
# 무언가를 보는 남성 34040
# 가르마를 탄 남성  34041
# 감정이 북받친듯한 남성 34042
# 베이지색 자켓을 입은 남성 34043
# 머리가 단정한 남성  34044
# 무언가를 보는 남성  34045
# 가르마를 탄 남성  34046
# 감동받은 남성 34047
# 베이지색 자켓을 입은 남성 34048
# 머리가 단정한 남성  34049
# 무언가를 보는 남성  34050
# 가르마를 탄 남성  34051
# 감정이 북받친듯한 남성 34052
# 스웨터를 입은 남성  34053
# 머리가 단정한 남성  34054
# 무언가를 보는 남성  34055
# 가르마를 탄 남성  34056
# 감동받은 남성 34057
# 스웨터를 입은 남성  34058
# 머리가 단정한 남성  34059
# 무언가를 보는 남성  34060
# 가르마를 탄 남성  34061
# 감동받은 남성 34062
# 스웨터를 입은 남성  34063
# 머리가 단정한 남성  34064
# 무언가를 보는 남성  34065
# 가르마를 탄 남성  34066
# 감동한듯한 표정의 남성 34067
# 스웨터를 입은 남성  34068
# 머리가 단정한 남성  34069
# 무언가를 보는 남성  34070
# 가르마를 탄 남성  34071
# 스웨터를 입은 남성  34072
# 머리가 단정한 남성  34073
# 앞머리를 정리한 남성  34074
# 가르마를 탄 남성  34075
# 무언가를 읽고있는 남성  34076
# 눈을 가늘게 뜬 남성  34077
# 머리가 단정한 남성  34078
# 앞머리를 정리한 남성  34079
# 옅은 미소를 띈 남성  34080
# 기뻐보이는 남성  34081
# 스웨터를 입은 남성  34082
# 유니폼을 입은 여자가 보인자 38654
# 종이를 든 여성  45748
# 점퍼를 입은 여성  45749
# 후드티를 입은 여성  45750
# 파마를 한 여성  45751
# 우유곽을 든 여성  45753
# 종이를 쥔 여성  45754
# 파마를 한 여성  45755
# 장갑을 낀 여성  45756
# 종이를 읽는 여성  45757
# 우유곽을 든 여성  45758
#  종이를 든 여성  45759
# 파마머리를 한 여성  45760
# 파마머리를 한 여성 45761
# 종이를 든 여성  45762
# 우유곽을 든 여성 45763
# 해맑게 웃는 여성  45764
# 파마머리를 한 여성  45765
# 종이를 든 여성  45766
# 점퍼를 입은 여성  45767
# 후드티를 입은 여성  45768
# 종이를 읽는 여성  45769
# 파마머리를 한 여성  45775
# 종이를 든 여성  45776
# 점퍼를 입은 여성 45777
# 후드티를 입은 여성  45778
# 어딘가를 응시하는 여성  45779
# 서로를 마주보는 두여성  45780
# 종이를 든 한 여성  45781
# 우유팩을 든 한 여성 45782
# 장갑을 낀 한 여성 45783
# 후드티를 입은 한 여성  45784
# 진지한 표정의 여성  45785
# 머리에 삔을 꽂은 여성  45786
# 종이를 읽고 있는 여성 45787
# 고개를 숙인채 쓰레기 더미를 뒤지는 여성   45790
# 노란 쓰레기통을 들고있는 여성  45793
# 박스더미를 앞에둔채 서있는 여성  45794
# 쓰레기장에 있는 두여성  45795
# 점퍼를 입은 여성 45796
# 파란색 코트를 입은 여성  45797
# 노란색 상자를 든 여성  45798
# 허리를 숙인 두 여성  45799
# 고개를 숙인채 쓰레기 더미를 뒤지는 여성 45800
# 노란 쓰레기통을 들고있는 여성  45803
# 박스더미를 앞에둔채 서있는 여성 45804
# 쓰레기장으로 들어오는 여성  45805
# 바구니를 든 여성  45806
# 빨간신발을 신은 여성  45807
# 회색 점퍼를 입은 여성  45808
# 쓰레기 더미들을 향해 걸어가는 여성  45809
# 표정이 굳은 남성  107671
# 서로를 마주보는 두 남성  107672
# 음식점에 있는 남성 107673
# 인상을 쓰는 남성  107674
# 양복을 입은 남성  107675
# 표정이 굳은 남성  107676
# 어두운 표정의 남성  107677
# 음식점에 있는 남성 107678
# 걱정스런 표정의 남성  107679
#  양복을 입은 남성  107680
# 양복을 입은 남성  107681
# 상대방을 노려보는 남성  107682
#  음식점에 있는 남성 107683
# 어두운 표정의 남성  107684
# 표정이 굳은 남성  107685
# 인상을 쓰고있는 남성  107686
# 상대방을 노려보는 남성  107687
# 음식점에 있는 남성 107688
# 표정이 굳은 남성  107689
#  인상을 쓰고있는 남성 107690
# 상대방을 노려보는 남성  107691
# 음식점에 있는 남성 107692
# 양복을 입은 남성 107693
# 걱정스런 눈빛에 남성  107694
# 인상을 쓰고있는 남성  107695
# 상대방을 노려보는 남성  107696
# 음식점에 있는 남성  107697
# 양복을 입은 남성  107698
# 젓가락을 쥔 남성  107703
# 넥타이를 맨 남성  107704
# 밥먹을 준비를 하는 남성  107705
# 서로 마주보고 있는 두 남성  107706
# 물잔을 옆에 두고 있는 남성  107707
# 초점이 풀린 남성  107708
# 무표정을 하고 있는 남성  107709
# 음식점에 온 남성  107710
# 음식을 먹을 준비를 하는 남성  107711
# 젓가락질을 하는 남성  107712
# 음식점에 온 두 남성 107713
# 양복을 입은 두 남성  107714
# 서로를 마주보고 앉은 두 남성  107715
# 먹을 준비를 하는 두 남성  107716
# 서로를 마주보고 앉은 두 남성  107717
# 먹을 준비를 하는 두 남성  107718
# 음식점에 온 두 남성  107719
# 넥타이를 푼 남성  107720
# 서로를 마주보고 앉은 두 남성  107721
# 젓가락질을 하는 남성  107722
# 먹을 준비를 하는 두 남성  107723
# 음식점에 온 두 남성  107724
# 양복을 입은 두 남성 107725
# 양복을 입은 두 남성  107726
# 음식점에 온 두 남성  107727
# 넥타이를 풀은 남성  107728
# 먹을 준비를 하는 두 남성  107729
# 양복을 입은 두 남성  107730
# 음식점에 온 두 남성  107731
# 먹을 준비를 하는 두 남성  107732
# 젓가락질을 하는 남성  107733
# 서로를 마주보고 앉은 두 남성  107734
# 서로를 마주보는 두 남성  107735
# 음식이 식탁에 올려져 있음 107736
# 먹을 준비를 하는 두 남성  107737
# 익어가는 감자탕이 남성들 사이에 있음  107738
#  양복을 입은 두 남성  107739
# 양복을 입은 두 남성  107740
#  익어가는 감자탕이 남성들 사이에 있음  107741
# 먹을 준비를 하는 두 남성  107742
# 음식이 식탁에 올려져 있음 107743
# 서로를 마주보는 두 남성 107744
# 양복을 입은 두 남성  107745
# 익어가는 감자탕이 남성들 사이에 있음  107746
# 먹을 준비를 하는 두 남성  107747
# 음식이 식탁에 올려져 있음 107748
# 서로를 마주보는 두 남성  107749
# 음식을 입에 넣으려하는 남성  107755
# 입을 벌리고 있는 남성  107756
# 뜨거운 김이 올라오는 음식을 먹는 남성  107757
# 양복을 입은 남성  107758
# 음식점에 온 남성  107759
# 음식을 먹고있는 남성  107760
# 넥타이를 맨 남성  107761
# 음식점에 온 남성  107762
# 인상을 쓰는 남성  107763
# 맛을 음미하는 남성  107764

# %%
df_ch_an2
# Out:
#                                                      사진경로  \
# 0       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 1       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 2       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 3       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 4       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# ...                                                   ...
# 119840  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119841  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119842  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119843  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119844  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
#
#                                           사진이름  \
# 0       KETI_SHOT_0000145756_KM_0000000448.jpg
# 1       KETI_SHOT_0000145756_KM_0000000448.jpg
# 2       KETI_SHOT_0000145756_KM_0000000448.jpg
# 3       KETI_SHOT_0000145756_KM_0000000448.jpg
# 4       KETI_SHOT_0000145756_KM_0000000448.jpg
# ...                                        ...
# 119840  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119841  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119842  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119843  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119844  KETI_SHOT_0000148199_KM_0000004318.jpg
#
#                                               캡셔닝_데이터(종합)  \
# 0       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 1       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 2       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 3       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 4       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# ...                                                   ...
# 119840  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119841  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119842  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119843  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119844  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
#
#                      캡셔닝_데이터
# 0                    남자들이 있다
# 1             남자들은 서로 쳐다보고있다
# 2                 남자는 검정머리이다
# 3       남자는 흰 셔츠를 입고있다다다다다다다
# 4                남자는 옆을 보고있다
# ...                      ...
# 119840         여자가 앞쪽을 보고 있다
# 119841         여자는 입을 다물고 있다
# 119842    여자는 외투를 입었다다다다다다다다
# 119843      여자의 외투에는 털이 달려있다
# 119844            여자는 야외에 있다
#
# [119845 rows x 4 columns]

# %%
df_ch_an2.to_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(완료).csv', index = False)
df_ch_an2 = pd.read_csv('C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final Project/Data/IC_Data/멀티모달_데이터정리(완료).csv')
df_ch_an2
# Out:
#                                                      사진경로  \
# 0       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 1       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 2       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 3       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 4       C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# ...                                                   ...
# 119840  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119841  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119842  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119843  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
# 119844  C:/Workspace/python/빅데이터 지능형서비스 개발 팀프로젝트/Final...
#
#                                           사진이름  \
# 0       KETI_SHOT_0000145756_KM_0000000448.jpg
# 1       KETI_SHOT_0000145756_KM_0000000448.jpg
# 2       KETI_SHOT_0000145756_KM_0000000448.jpg
# 3       KETI_SHOT_0000145756_KM_0000000448.jpg
# 4       KETI_SHOT_0000145756_KM_0000000448.jpg
# ...                                        ...
# 119840  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119841  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119842  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119843  KETI_SHOT_0000148199_KM_0000004318.jpg
# 119844  KETI_SHOT_0000148199_KM_0000004318.jpg
#
#                                               캡셔닝_데이터(종합)  \
# 0       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 1       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 2       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 3       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# 4       ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남...
# ...                                                   ...
# 119840  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119841  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119842  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119843  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
# 119844  ['여자가 앞쪽을 보고 있다', '여자는 입을 다물고 있다', '여자는 외투를 입었...
#
#                      캡셔닝_데이터
# 0                    남자들이 있다
# 1             남자들은 서로 쳐다보고있다
# 2                 남자는 검정머리이다
# 3       남자는 흰 셔츠를 입고있다다다다다다다
# 4                남자는 옆을 보고있다
# ...                      ...
# 119840         여자가 앞쪽을 보고 있다
# 119841         여자는 입을 다물고 있다
# 119842    여자는 외투를 입었다다다다다다다다
# 119843      여자의 외투에는 털이 달려있다
# 119844            여자는 야외에 있다
#
# [119845 rows x 4 columns]

# %%
from PIL import Image
n = 107747
print(df_ch_an2['캡셔닝_데이터(종합)'][n])
print(df_ch_an2['캡셔닝_데이터'][n])
Image.open(df_ch_an2['사진경로'][n])
# Out:
# ['양복을 입은 두남성 ', '익어가는 감자탕이 남성들 사이에 있음 ', '먹을 준비를 하는 두남성 ', '음식이 식탁에 올려져 있음', '서로를 마주보는 두남성 ']
# 먹을 준비를 하는 두 남성
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x201B565D400>
